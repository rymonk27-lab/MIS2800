# %% [markdown]
# <a href="https://colab.research.google.com/github/rymonk27-lab/MIS2800/blob/main/HW3Monk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.IntegrityError) UNIQUE constraint failed: Marketing_Brands.brand_id
# [SQL: INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketi
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and brand
SELECT brand_name, brand_type
FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages')]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT * FROM Marketing_Brands
WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
-- Instructions: Fix the code to display the brand names that have a bud
SELECT brand_name
FROM Marketing_Brands
WHERE brand_budget > 100000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Pepsi',), ('He_Gets_Us',), ('Dr_Pepper',)]

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in Colab witho
# %%sql
SELECT *
FROM Marketing_Brands
WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000)]

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is Snacks or Bevera
SELECT * FROM Marketing_Brands WHERE brand_type IN ('Snacks', 'Beverages')
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in DESC order. Display o
SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a table showing all the co
import sqlite3
import pandas as pd

conn = sqlite3.connect('AdCampaigns2026.db')
df = pd.read_sql_query("SELECT * FROM Marketing_Brands;", conn)
df
# Out:
#    brand_id  brand_name  brand_type  brand_budget
# 0         1     Doritos      Snacks       7000000
# 1         2         AWS  Technology      15000000
# 2         3       Pepsi   Beverages       2000000
# 3         4  He_Gets_Us   Religious       1000000
# 4         5   Dr_Pepper   Beverages       5000000

# %% [markdown]
# #1. The word TABLE was missing.
# #2. Missing INTO + the table name.
# #3. Missing the * after SELECT.
# #4. Had to add brand_name and brand_type after select.
# #5. Had to add WHERE brand_type = 'Religious';
# #6. Had to add WHERE brand_budget > 100000;
# #7. Had to add WHERE brand_budget > 7000000;
# #8. Had to add WHERE brand_type IN ('Snacks', 'Beverages');
# #9. The pdf was cut off but I selected brand_name, and brand_budget, ordered by budget in desc.
# #10. Had to create a whole table.
